# %% [markdown]
# Upload yolov5_setup2.rar to content folder

# %% [markdown]
# Rename yolov5_setup2.rar to yolov5.rar

# %%
#UNZIP FOLDER WITH ALL NECESSARY FILES
# !pip install unrar
# !unrar x /content/yolov5.rar
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %% [markdown]
# You might need to create a new yolov5 folder and move the original one inside it to satisfy the path definitions

# %% [markdown]
# Rename /content/yolov5/yolov5_setup2 to yolov5

# %%
#INSTALL YOLOV5 OBJECT DETECTION MODEL
# %cd /content/yolov5/yolov5
# %pip install -qr requirements.txt  # install
import torch
import utils
display = utils.notebook_init()  # checks
# %pip install ultralytics
# !pip install mlflow --quiet
# Out:
# YOLOv5 🚀 v7.0-120-g3e55763 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.4/78.2 GB disk)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 9.7 MB/s eta 0:00:00

# %% [markdown]
# Before running detect.py, ensure:-
#
#
#
# 1.   best.pt (network weights) located in same place as specified in --yolo_model below
# 2.   video being processed is located in same place as specified in --source below

# %%
#RUN DETECTION SCRIPT: ONLY NEED TO CHANGE --SOURCE, POSSIBLY IMG SIZE AND ANY OPTIONAL CONFIGURATIONS LISTED AT THE END OF detect.py FILE SUCH AS --save-txt or --save-vid
# !python /content/yolov5/yolov5/detect.py --yolo_model /content/yolov5/yolov5/runs/train/exp3/weights/best.pt --source /content/yolov5/yolov5/data/175.mp4 --imgsz 768 --config_deepsort /content/yolov5/yolov5/deep_sort/configs/deep_sort.yaml --show-vid --save-vid --save-txt --agnostic
# Out:
# /content/yolov5/yolov5/deep_sort/deep/reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# 2023-11-09 16:33:25.759559: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-09 16:33:25.759616: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-09 16:33:25.759655: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# Download the following results from detection using cell below
#
#
# 1.   /content/yolov5/yolov5/finalResultsArranged.csv (classification, detection and tracking results)
# 2.   /content/tuyerePlumeWidthTable2.csv (plume width at tuyere results)
# 3.   /content/yolov5/yolov5/runs/track/exp/plume100.mp4 (output video)

# %%
from google.colab import files
files.download('/content/finalResultsArranged.csv')
files.download('/content/tuyerePlumeWidthTable2.csv')
files.download('/content/yolov5/yolov5/runs/track/exp6/plume100.mp4')
#                                                 ^^^^
#MAKE SURE THE CORRECT EXPERIMENT IS CHOSEN (i.e, exp, exp2, exp3, exp4.. etc). Comes into play when you run multiple experiments.
#Hovering over the files in file explorer tells you when they were created which is useful when ensuring the correct one is specified.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-440174d970ee> in <cell line: 2>()
#       1 from google.colab import files
# ----> 2 files.download('/content/finalResultsArranged.csv')
#       3 files.download('/content/tuyerePlumeWidthTable2.csv')
#       4 files.download('/content/yolov5/yolov5/runs/track/exp6/plume100.mp4')
#       5 #                                                 ^^^^
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/finalResultsArranged.csv

# %%
import os
os.remove("/content/tuyerePlumeWidthTable2.csv")
os.remove("/content/finalResultsArranged.csv")
os.remove("/content/finalResult2.csv")
os.remove("/content/finalResult3.csv")
os.remove("/content/finalResult4.csv")
os.remove("/content/finalResult5.csv")
os.remove("/content/finalResult6.csv")
os.remove("/content/finalResult7.csv")
os.remove("/content/finalResult8.csv")
os.remove("/content/finalResult9.csv")
os.remove("/content/finalResult10.csv")
os.remove("/content/finalResult11.csv")
os.remove("/content/finalResult12.csv")
os.remove("/content/finalResult13.csv")
os.remove("/content/finalResult14.csv")
os.remove("/content/finalResult15.csv")





os.kill(os.getpid(), 9)

# %% [markdown]
# After one set of results has been saved successfully, the runtime needs to clear out previous results before collecting new ones to ensure they do not just add to the previous files.
#
# The number of finalResultX.csv files produced is equal to the number of plumes detected so comment out or add the appropriate number to the cell below using '#' to comment out lines. It is important they are removed before the next experiment. You will know how many to delete based on how many you can see in the file explorer when detect.py is finished. Make sure you click the refresh button above the file explorer before doing this to ensure all results files are shown.
#
# The final line in the cell below resets the runtime which will clear variables saved in the system (not the same as deleting all your files but the os.remove commands will delete files that need to be deleted anyway).

# %%
import os
os.remove("/content/yolov5/yolov5/finalResultsArranged.csv")
os.remove("/content/yolov5/yolov5/tuyerePlumeWidthTable2.csv")
os.remove("/content/yolov5/yolov5/finalResult1.csv")
os.remove("/content/yolov5/yolov5/finalResult2.csv")
os.remove("/content/yolov5/yolov5/finalResult3.csv")
os.remove("/content/yolov5/yolov5/finalResult4.csv")
os.remove("/content/yolov5/yolov5/finalResult5.csv")
os.remove("/content/yolov5/yolov5/finalResult6.csv")
os.remove("/content/yolov5/yolov5/finalResult7.csv")
os.remove("/content/yolov5/yolov5/finalResult8.csv")
os.remove("/content/yolov5/yolov5/finalResult9.csv")
os.remove("/content/yolov5/yolov5/finalResult10.csv")
os.remove("/content/yolov5/yolov5/finalResult11.csv")
os.remove("/content/yolov5/yolov5/finalResult12.csv")
os.remove("/content/yolov5/yolov5/finalResult13.csv")
os.remove("/content/yolov5/yolov5/finalResult14.csv")
os.remove("/content/yolov5/yolov5/finalResult15.csv")





os.kill(os.getpid(), 9)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bd81724ccc1c> in <cell line: 2>()
#       1 import os
# ----> 2 os.remove("/content/yolov5/yolov5/finalResultsArranged.csv")
#       3 os.remove("/content/yolov5/yolov5/tuyerePlumeWidthTable2.csv")
#       4 os.remove("/content/yolov5/yolov5/finalResult1.csv")
#       5 os.remove("/content/yolov5/yolov5/finalResult2.csv")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/yolov5/yolov5/finalResultsArranged.csv'
